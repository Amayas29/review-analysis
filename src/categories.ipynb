# %%
from iads import loading_data as loader
from iads import traitement_data as traitement

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Chargement des données

# %% [markdown]
# bson -> DF

# %%
df_avis = loader.load_dataframe("avis.bson")

# %%
df_jeux = loader.load_dataframe("details.bson")

# %% [markdown]
# ## Fichier jeux

# %%
df_jeux.head()
# Out:
#    Nombre d'avis rectifiés  Note rectifiée  \
# 0                     10.0            8.40
# 1                     17.0            7.29
# 2                      9.0            7.22
# 3                      0.0            0.00
# 4                     24.0            8.79
#
#                                                  url  Note Finkel  \
# 0  https://www.trictrac.net/jeu-de-societe/marvel...         8.74
# 1  https://www.trictrac.net/jeu-de-societe/mariposas         7.68
# 2    https://www.trictrac.net/jeu-de-societe/quetzal         7.42
# 3  https://www.trictrac.net/jeu-de-societe/alien-...         0.00
# 4   https://www.trictrac.net/jeu-de-societe/the-loop         9.70
#
#    Nombre d'avis                       _id                     titre  \
# 0           19.0  63c5790a08b9fb9fd8f26ec8             Marvel United
# 1           33.0  63c5790a08b9fb9fd8f26ec9                 Mariposas
# 2           28.0  63c5790b08b9fb9fd8f26eca                   Quetzal
# 3            4.0  63c5790b08b9fb9fd8f26ecb  Alien - Kit de Démarrage
# 4           72.0  63c5790b08b9fb9fd8f26ecc                  The LOOP
#
#                                              casting  Note  \
# 0  Par Eric Lang et Andrea ChiarvesioIllustré par...  7.58
# 1  Par Elizabeth HargraveIllustré par Matt Paquet...  7.39
# 2  Par Alexandre GarciaIllustré par Nastya LehnÉd...  8.18
# 3                Édité par Arkhane Asylum Publishing  9.00
# 4  Par Maxime Rambourg et Théo RivièreIllustré pa...  8.75
#
#                                           categories  \
# 0                                                NaN
# 1                                                NaN
# 2  Enchères|Aventures dans la jungle|Collection /...
# 3                                                NaN
# 4  Card-driven|Combinaison|Coopération|Deck build...
#
#                                          description  \
# 0  \n                      Marvel United : Unis c...
# 1  \n                      Chaque année, au print...
# 2  \n                      Vous êtes à la tête d’...
# 3  \n                      Un Kit de démarrage co...
# 4  \n                      Le Dr Foo a créé une t...
#
#                       gameplay                       full_title
# 0        1 à 4|14 ans et +|45              Marvel United (2020)
# 1        2 à 5|14 ans et +|60                  Mariposas (2020)
# 2         2 à 5|8 ans et +|45                    Quetzal (2020)
# 3  à partir de 1|12 ans et +|~  Alien - Kit de Démarrage (2020)
# 4        1 à 4|12 ans et +|60                   The LOOP (2020)

# %% [markdown]
# 1. Existence des jeux dupliqués

# %% [markdown]
# On supprime l'attribut `_id` généré par le `scrapping` pour mettre en evidences la duplication des jeux

# %%
df_jeux_up = df_jeux.drop(["_id"], axis=1)
df_jeux_up = df_jeux_up.drop_duplicates()

# %%
len_before = len(df_jeux)
len_after  = len(df_jeux_up)

# %%
plt.bar(['data init', 'data unique'], [len_before, len_after], width=0.2)
plt.show()

# %%
val, counts = np.unique(df_jeux_up["titre"], return_counts=True)

plt.plot(counts)
plt.show()

# %% [markdown]
# 2. Version des jeux !!

# %%
list_same_title = []

for v in val[counts != 1]:
    a = df_avis[df_avis["title"] == v]
    
    if len(a) > 1:
        list_same_title.append(a)

# %%
list_same_title[1].head()
# Out:
#        title  note      author  \
# 163033  1830   5.4  Mesophylle
# 241489  1830  10.0      20.100
# 241490  1830  10.0      maksen
# 241491  1830  10.0   Elendriel
# 241492  1830  10.0      Wufnir
#
#                                                       url  \
# 163033  https://www.trictrac.net/jeu-de-societe/1830-0...
# 241489  https://www.trictrac.net/jeu-de-societe/1830/a...
# 241490  https://www.trictrac.net/jeu-de-societe/1830/a...
# 241491  https://www.trictrac.net/jeu-de-societe/1830/a...
# 241492  https://www.trictrac.net/jeu-de-societe/1830/a...
#
#                                                   comment  \
# 163033  Un petit wargame assez light, aux règles très ...
# 241489  Le plus intéressant avec ce jeu est que le has...
# 241490  Il faut pas mal de combustible pour s'attaquer...
# 241491  Le premier de la série déclancheur de l'engoue...
# 241492  Les pertie que j'ai faites se sont terminées d...
#
#                              _id  \
# 163033  63c67b8a993b727dc2a9c9ce
# 241489  63c68339993b727dc2aafc46
# 241490  63c68339993b727dc2aafc47
# 241491  63c68339993b727dc2aafc48
# 241492  63c68339993b727dc2aafc49
#
#                                               review_href  \
# 163033  https://www.trictrac.net/avis/pour-les-belges-...
# 241489  https://www.trictrac.net/avis/le-bonheur-d-etr...
# 241490  https://www.trictrac.net/avis/fais-chauffer-la...
# 241491         https://www.trictrac.net/avis/le-premier-4
# 241492         https://www.trictrac.net/avis/excellent-82
#
#              date_published  treated  \
# 163033  2013-03-12 14:23:55     True
# 241489  2001-11-19 12:28:35     True
# 241490  2012-09-11 12:29:05     True
# 241491  2011-11-07 12:29:02     True
# 241492  2005-07-29 12:28:39     True
#
#                                              title_review
# 163033  Pour les Belges (et surtout Bruxellois) friand...
# 241489                      le bonheur d'être le meilleur
# 241490                       Fais chauffer la chaudière !
# 241491                                         le premier
# 241492                                          Excellent

# %%
df_jeux_up["_id"] = df_jeux_up.apply(traitement.update_title_jeux, axis=1)

df_jeux_up.head()
# Out:
#    Nombre d'avis rectifiés  Note rectifiée  \
# 0                     10.0            8.40
# 1                     17.0            7.29
# 2                      9.0            7.22
# 3                      0.0            0.00
# 4                     24.0            8.79
#
#                                                  url  Note Finkel  \
# 0  https://www.trictrac.net/jeu-de-societe/marvel...         8.74
# 1  https://www.trictrac.net/jeu-de-societe/mariposas         7.68
# 2    https://www.trictrac.net/jeu-de-societe/quetzal         7.42
# 3  https://www.trictrac.net/jeu-de-societe/alien-...         0.00
# 4   https://www.trictrac.net/jeu-de-societe/the-loop         9.70
#
#    Nombre d'avis                     titre  \
# 0           19.0             Marvel United
# 1           33.0                 Mariposas
# 2           28.0                   Quetzal
# 3            4.0  Alien - Kit de Démarrage
# 4           72.0                  The LOOP
#
#                                              casting  Note  \
# 0  Par Eric Lang et Andrea ChiarvesioIllustré par...  7.58
# 1  Par Elizabeth HargraveIllustré par Matt Paquet...  7.39
# 2  Par Alexandre GarciaIllustré par Nastya LehnÉd...  8.18
# 3                Édité par Arkhane Asylum Publishing  9.00
# 4  Par Maxime Rambourg et Théo RivièreIllustré pa...  8.75
#
#                                           categories  \
# 0                                                NaN
# 1                                                NaN
# 2  Enchères|Aventures dans la jungle|Collection /...
# 3                                                NaN
# 4  Card-driven|Combinaison|Coopération|Deck build...
#
#                                          description  \
# 0  \n                      Marvel United : Unis c...
# 1  \n                      Chaque année, au print...
# 2  \n                      Vous êtes à la tête d’...
# 3  \n                      Un Kit de démarrage co...
# 4  \n                      Le Dr Foo a créé une t...
#
#                       gameplay                       full_title  \
# 0        1 à 4|14 ans et +|45              Marvel United (2020)
# 1        2 à 5|14 ans et +|60                  Mariposas (2020)
# 2         2 à 5|8 ans et +|45                    Quetzal (2020)
# 3  à partir de 1|12 ans et +|~  Alien - Kit de Démarrage (2020)
# 4        1 à 4|12 ans et +|60                   The LOOP (2020)
#
#                       _id
# 0           marvel-united
# 1               mariposas
# 2                 quetzal
# 3  alien-kit-de-demarrage
# 4                the-loop

# %%
val, counts = np.unique(df_jeux_up["_id"], return_counts=True)

plt.plot(counts)
plt.show()

# %%
df_jeux_up.head()
# Out:
#    Nombre d'avis rectifiés  Note rectifiée  \
# 0                     10.0            8.40
# 1                     17.0            7.29
# 2                      9.0            7.22
# 3                      0.0            0.00
# 4                     24.0            8.79
#
#                                                  url  Note Finkel  \
# 0  https://www.trictrac.net/jeu-de-societe/marvel...         8.74
# 1  https://www.trictrac.net/jeu-de-societe/mariposas         7.68
# 2    https://www.trictrac.net/jeu-de-societe/quetzal         7.42
# 3  https://www.trictrac.net/jeu-de-societe/alien-...         0.00
# 4   https://www.trictrac.net/jeu-de-societe/the-loop         9.70
#
#    Nombre d'avis                     titre  \
# 0           19.0             Marvel United
# 1           33.0                 Mariposas
# 2           28.0                   Quetzal
# 3            4.0  Alien - Kit de Démarrage
# 4           72.0                  The LOOP
#
#                                              casting  Note  \
# 0  Par Eric Lang et Andrea ChiarvesioIllustré par...  7.58
# 1  Par Elizabeth HargraveIllustré par Matt Paquet...  7.39
# 2  Par Alexandre GarciaIllustré par Nastya LehnÉd...  8.18
# 3                Édité par Arkhane Asylum Publishing  9.00
# 4  Par Maxime Rambourg et Théo RivièreIllustré pa...  8.75
#
#                                           categories  \
# 0                                                NaN
# 1                                                NaN
# 2  Enchères|Aventures dans la jungle|Collection /...
# 3                                                NaN
# 4  Card-driven|Combinaison|Coopération|Deck build...
#
#                                          description  \
# 0  \n                      Marvel United : Unis c...
# 1  \n                      Chaque année, au print...
# 2  \n                      Vous êtes à la tête d’...
# 3  \n                      Un Kit de démarrage co...
# 4  \n                      Le Dr Foo a créé une t...
#
#                       gameplay                       full_title  \
# 0        1 à 4|14 ans et +|45              Marvel United (2020)
# 1        2 à 5|14 ans et +|60                  Mariposas (2020)
# 2         2 à 5|8 ans et +|45                    Quetzal (2020)
# 3  à partir de 1|12 ans et +|~  Alien - Kit de Démarrage (2020)
# 4        1 à 4|12 ans et +|60                   The LOOP (2020)
#
#                       _id
# 0           marvel-united
# 1               mariposas
# 2                 quetzal
# 3  alien-kit-de-demarrage
# 4                the-loop

# %%
df_jeux_up["creators"] = df_jeux_up.apply(traitement.extract_creators, axis=1)
df_jeux_up["illustrators"] = df_jeux_up.apply(traitement.extract_illustrators, axis=1)
df_jeux_up["editors"] = df_jeux_up.apply(traitement.extract_editors, axis=1)
df_jeux_up["distributors"] = df_jeux_up.apply(traitement.extract_distributors, axis=1)

# %%
import re

game_play = df_jeux_up["gameplay"].iloc[-2]

print(game_play)

[nb_joueurs, age_requis, temps_part] = game_play.split("|")

print(nb_joueurs)
nb_joueurs = re.sub(r'[a-zA-zà]*', '', nb_joueurs)

print(nb_joueurs)
# Out:
# jusqu'à 2|14 à 99 |240
# jusqu'à 2
# '2

# %%
df_jeux_up["gameplay"]
# Out:
# 0              1 à 4|14 ans et +|45
# 1              2 à 5|14 ans et +|60
# 2               2 à 5|8 ans et +|45
# 3        à partir de 1|12 ans et +|~
# 4              1 à 4|12 ans et +|60
#                     ...
# 20228           2 à 4|4 ans et +|10
# 20229        jusqu'à 2|14 à 99 |180
# 20230        jusqu'à 2|14 à 99 |180
# 20231        jusqu'à 2|14 à 99 |240
# 20232           2 à 6|4 ans et +|15
# Name: gameplay, Length: 16873, dtype: object

# %%
tmp = df_jeux_up[df_jeux_up["creators"].isna() & df_jeux_up["illustrators"].isna() & df_jeux_up["distributors"].isna() & df_jeux_up["editors"].isna()]
len(tmp)
# Out:
# 286

# %%
tmp = df_jeux_up[df_jeux_up["creators"].isna() & df_jeux_up["illustrators"].isna() & df_jeux_up["distributors"].isna() & df_jeux_up["casting"].isna() & df_jeux_up["editors"].isna()]

len(tmp)
# Out:
# 286
